# %%
import pandas as pd

# %%
#glob.glob("D:\Stock Market\Daily\Test\*.xls")
#for f in glob.glob('D:\Stock Market\Daily\Test\*.xls'):
df = pd.read_excel('D:\Stock Market\Daily\Test\ALEX_CAD.xls'.skiprow)
#df.columns = map(str.capitalize, df.columns)
df.rename(columns={'VOLUME': 'Volume_BTC'}, inplace=True)
df
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'ascii'
#      MetaStock(tm) data file \\ALEX.CA\  Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                   PER        DATE       TIME       OPEN
# 1                                     D  04/30/2002   00:00:00    9.85687
# 2                                     D  05/02/2002   00:00:00    9.86237
# 3                                     D  05/07/2002   00:00:00     9.8611
# 4                                     D  05/08/2002   00:00:00    9.86322
# ...                                 ...         ...        ...        ...
# 2730                                  D  04/01/2020   00:00:00        5.5
# 2731                                  D  04/06/2020   00:00:00       5.51
# 2732                                  D  04/07/2020   00:00:00       5.64
# 2733                                  D  04/08/2020   00:00:00       5.52
# 2734                                  D  04/09/2020   00:00:00       5.52
#
# ...

# %%
df.columns = map(str.capitalize, df.columns)

# %%
df
# Out:
#      Metastock(tm) data file \\alex.ca\  Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                   PER        DATE       TIME       OPEN
# 1                                     D  04/30/2002   00:00:00    9.85687
# 2                                     D  05/02/2002   00:00:00    9.86237
# 3                                     D  05/07/2002   00:00:00     9.8611
# 4                                     D  05/08/2002   00:00:00    9.86322
# ...                                 ...         ...        ...        ...
# 2730                                  D  04/01/2020   00:00:00        5.5
# 2731                                  D  04/06/2020   00:00:00       5.51
# 2732                                  D  04/07/2020   00:00:00       5.64
# 2733                                  D  04/08/2020   00:00:00       5.52
# 2734                                  D  04/09/2020   00:00:00       5.52
#
#      Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# ...

# %%
df.rename(columns={'Volume':'Volume_BTC'}, inplace=True)

# %%
df
# Out:
#      PER        DATE      Time       Open       High        Low      Close  \
# 0      D  08/28/2007  00:00:00  40.880001  45.180000  40.880001  42.549999
# 1      D  08/29/2007  00:00:00  40.430000  44.669998  40.430000  41.410000
# 2      D  08/30/2007  00:00:00  39.500000  39.830002  39.340000  39.529999
# 3      D  09/02/2007  00:00:00  37.560001  41.500000  37.560001  41.299999
# 4      D  09/03/2007  00:00:00  43.360001  43.360001  41.750000  42.970001
# ...   ..         ...       ...        ...        ...        ...        ...
# 2070   D  04/02/2020  00:00:00   7.470000   7.520000   7.470000   7.500000
# 2071   D  04/05/2020  00:00:00   7.450000   7.850000   7.450000   7.850000
# 2072   D  04/07/2020  00:00:00   7.500000   7.520000   7.480000   7.490000
# 2073   D  04/08/2020  00:00:00   7.450000   8.240000   7.450000   8.240000
# 2074   D  04/09/2020  00:00:00   8.660000   8.670000   8.100000   8.670000
#
#       VOLUME
# 0      81060
# 1       8906
# 2       8663
# ...
