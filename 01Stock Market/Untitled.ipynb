# %% [markdown]
# # Study any Company on the American Stock Market

# %% [markdown]
# ### imported the stock price

# %% [markdown]
# #### import data from yahoo finnace

# %%
import talib as ta
import matplotlib.pyplot as plt
plt.style.use('bmh')
import yfinance as yf
aapl = yf.download('goog', '2019-1-1','2020-4-8') # use if import data from yahoo finnace Example : goog Company
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# #### if import data from file(chaing Close to AdjClose in file)

# %%
aapl=pd.read_excel('D:\Stock Market\Daily\Test\EGX30C.xlsx')

# %% [markdown]
# ### Technical Analysis Indicator

# %% [markdown]
# #### Parabolic SAR

# %%
aapl['SAR'] = ta.SAR(aapl['High'],aapl['Low'],14)
aapl[['SAR','Close']].plot(figsize=(15,15))
plt.show()

# %% [markdown]
# #### Simple Moving Average and the Exponential Moving Average

# %%
aapl['Simple MA'] = ta.SMA(aapl['Close'],14)
aapl['EMA'] = ta.EMA(aapl['Close'], timeperiod = 14)
# Plot
aapl[['Close','Simple MA','EMA']].plot(figsize=(15,15))
plt.show()

# %% [markdown]
# #### Bollinger Bands

# %%
aapl['upper_band'], aapl['middle_band'], aapl['lower_band'] = ta.BBANDS(aapl['Close'], timeperiod =20)
# Plot
aapl[['Close','upper_band','middle_band','lower_band']].plot(figsize=(15,15))
plt.show()

# %%
aapl['upper_band'], aapl['middle_band'], aapl['lower_band'] = ta.BBANDS(aapl['Close'], timeperiod =20)

# %% [markdown]
# #### RSI

# %%
aapl['RSI'] = ta.RSI(aapl['Close'],14)
aapl['RSI'].plot(figsize=(15,15))
plt.show()

# %% [markdown]
# ####  Stochastic oscillators

# %%
aapl['slowk'], aapl['slowd'] = ta.STOCH(aapl['High'], aapl['Low'], aapl['Close'], fastk_period=14, slowk_period=3, slowk_matype=0, slowd_period=3, slowd_matype=0)
aapl[['slowk','slowd']].plot(figsize=(15,15))
plt.show()

# %%
aapl['fastk'], aapl['fastd'] = ta.STOCHF(aapl['High'], aapl['Low'], aapl['Close'], fastk_period=14, fastd_period=3, fastd_matype=0)
aapl[['fastk','fastd']].plot(figsize=(15,15))
plt.show()

# %% [markdown]
# #### CCI

# %%
aapl['CCI'] = ta.CCI(aapl['High'],aapl['Low'],aapl['Close'],14)
aapl['CCI'].plot(figsize=(15,15))
plt.show()
